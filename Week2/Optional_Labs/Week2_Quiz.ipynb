# %% [markdown]
# # 1번
# 다음 그림을 보고,feature scaling중에 사용되는 단계는 무엇인지 고르시오.
# ![1번문제.PNG](data:image/png;base64,...)
#
# * (1)각 값에서 평균을 뺀 다음 (최대값-최소값)으로 나눕니다
# * (2)각 값에서 평균을 더한 다음 (최대-최소)로 나눕니다.

# %% [markdown]
# 정답 :

# %% [markdown]
# #2번
# 다음 그림을 보고 $x^{(3)}_4$에 해당하는 element(요소)값을 쓰시오.
#
# #![2번문제.PNG](data:image/png;base64,...)

# %% [markdown]
# 정답 :

# %% [markdown]
# #3번
# 다음 중 vectorization에 대해 적절한 것을 고르시오.
# - (1) code를 매우 짧게 만들어준다
# - (2) 모두 정답
# - (3) 정답 없음
# - (4) 코드를 더 빠르게 만들어준다
# - (5) 병렬 처리가 쉽고, 계산 속도를 빠르게 해준다.

# %% [markdown]
# ## 4번
# Gradient descent가 2배 빠르게 수렴하려면, 항상 learning rate를 2배 늘려주는 기법을 활요해야 한다
# * (1) True
# * (2) False

# %% [markdown]
# 정답 :

# %% [markdown]
# # 5번
# 다차원(다항식) 회귀를 사용하는 경우 예측된 값(predicted value)가 반드시 입력 피처(input_features)X에 대해 반드시 선형 함수(linear function)일 필요는 없다.
# - (1) True
# - (2) False

# %% [markdown]
# 정답 :
